# %% [markdown]
# <a href="https://colab.research.google.com/github/RiddhimanRaut/Deep-Learning-based-CPR-estimation/blob/main/CPR_prediction_multivariate_LSTM_tobetrialled_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Standard Imports for RNNs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime

# %%
url = "https://github.com/RiddhimanRaut/Deep-Learning-based-CPR-estimation/blob/main/excel_dataset.xlsx?raw=true"
df = pd.read_excel(url)
#df = df[5::6] #Hour-wise Data
df.head()
# Out:
#              Date Time    CPRAVG       PROP  ...        O2     DRAFT        ETH
# 0  01.01.2009 00:10:00  0.428151  18.960609  ...  1.444160 -5.616851  75.809700
# 1  01.01.2009 00:20:00  0.427783  18.960360  ...  1.413894 -5.540349  75.810066
# 2  01.01.2009 00:30:00  0.427432  19.009649  ...  1.515123 -5.628389  75.552841
# 3  01.01.2009 00:40:00  0.427082  19.155710  ...  1.404055 -5.576591  75.580223
# 4  01.01.2009 00:50:00  0.426732  19.334640  ...  1.191485 -5.274679  75.638023
#
# [5 rows x 13 columns]

# %%
#Separating Date and Time
#To be used in plotting in X-axis
date_time = pd.to_datetime(df.pop('Date Time'), format='%d.%m.%Y %H:%M:%S') #pop command takes the Date Time Column out of df, so df no longer has that column.

# %% [markdown]
# We need to remove $Ethylene$ and $AI12201M$ columns as they are not controllable factors.

# %%
df = df.drop('ETHYLENE',axis=1)
df = df.drop('AI12201M',axis=1)
df.head()
# Out:
#      CPRAVG       PROP       BUT  ...        O2     DRAFT        ETH
# 0  0.428151  18.960609  3.973630  ...  1.444160 -5.616851  75.809700
# 1  0.427783  18.960360  3.973562  ...  1.413894 -5.540349  75.810066
# 2  0.427432  19.009649  4.181924  ...  1.515123 -5.628389  75.552841
# 3  0.427082  19.155710  3.950392  ...  1.404055 -5.576591  75.580223
# 4  0.426732  19.334640  3.689848  ...  1.191485 -5.274679  75.638023
#
# [5 rows x 10 columns]

# %%
#Variables for training
cols = list(df)[0:df.shape[1]]
#To enforce that values in these columns are actually float type data
df_for_rnn = df[cols].astype(float)

# %%
#Creating training_df and test_df
n = len(df)
training_df = df_for_rnn[0:int(n*0.7)]
test_set = df_for_rnn[int(n*0.7):n]

# %%
#Scaling the Dataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
#scaler = StandardScaler()
scaler = MinMaxScaler(feature_range = (0,1))
df_for_training_scaled = scaler.fit_transform(training_df) #Scales and converts to numpy object
print('Scaled Dataset:\n',df_for_training_scaled)
# Out:
# Scaled Dataset:
#  [[0.04261512 0.39141737 0.71843606 ... 0.54553167 0.061713   0.69995722]
#  [0.03834461 0.39139343 0.71841953 ... 0.53416085 0.09054363 0.69998058]
#  [0.03428528 0.39611563 0.76908826 ... 0.57219227 0.05736476 0.68357295]
#  ...
#  [0.94817084 0.28810413 0.68416253 ... 0.67555781 0.51802072 0.79587724]
#  [0.95048011 0.28807252 0.68538325 ... 0.68702255 0.51584291 0.79587529]
#  [0.95188739 0.28809554 0.70426883 ... 0.68955967 0.51498322 0.79587237]]

# %%
#Readying the Multivariate Input and Univariate Output

#initialisation
trainX = [] 
trainY = []

n_future = 10 #number of hours into the future
n_past = 200  #number of hours into the past

for i in range(n_past, len(df_for_training_scaled)-n_future+1):
  trainX.append(df_for_training_scaled[i-200:i,:])
  trainY.append(df_for_training_scaled[i+n_future-1:i+n_future,0])
trainX = np.array(trainX)   # shape 1: no of records, shape 2: past_days, shape 3: input_cols
trainY = np.array(trainY)   # shape 1: records, shape 2: future prediction data
print('TrainX shape = (%d,%d,%d)'%(trainX.shape[0],trainX.shape[1],trainX.shape[2]))
print('TrainY shape = (%d,%d)'%(trainY.shape[0],trainY.shape[1]))
# Out:
# TrainX shape = (8518,200,10)
# TrainY shape = (8518,1)

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping

model = Sequential()
model.add(LSTM(64,activation='sigmoid',return_sequences=True,input_shape = (trainX.shape[1],trainX.shape[2])))
model.add(LSTM(32,activation='sigmoid',return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(trainY.shape[1]))
opt = Adam(learning_rate= 1e-4)
model.compile(optimizer=opt,loss = 'mse')
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 200, 64)           19200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 31,649
# Trainable params: 31,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Let's traaaaaaaaaaaainnn
es_callback = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(trainX,trainY,epochs=2,batch_size= 2000,verbose=1,validation_split=0.2, callbacks= [es_callback])
# Out:
# Epoch 1/2
# 4/4 [==============================] - 8s 1s/step - loss: 1.5401 - val_loss: 1.2435
# Epoch 2/2
# 4/4 [==============================] - 5s 1s/step - loss: 0.7816 - val_loss: 0.5619

# %%
plt.plot(history.history['loss'],label = 'Training Loss')
plt.plot(history.history['val_loss'],label = 'Validation Loss')
plt.legend()

# %%
test_df_scaled = scaler.transform(test_set)
print("Length of the test dataset is %d." %len(test_df_scaled))
testX = []
for i in range(n_past,len(test_df_scaled)-n_future):
  # print(i)
  testX.append(test_df_scaled[i-n_past:i,:])
testX = np.array(testX)
testX.shape
# Out:
# Length of the test dataset is 3741.
# (3531, 200, 10)

# %%
predicted_CPRAVG = model.predict(testX)
predicted_CPRAVG = np.repeat(predicted_CPRAVG,test_df_scaled.shape[1],axis = -1)
predicted_CPRAVG = scaler.inverse_transform(predicted_CPRAVG)[:,0]
predicted_CPRAVG = predicted_CPRAVG.reshape(-1,1)
print(predicted_CPRAVG)
predicted_CPRAVGplot = np.empty_like(df)
predicted_CPRAVGplot[:,:] = np.nan
predicted_CPRAVGplot[training_df.shape[0]+n_past+n_future:df.shape[0],:] = predicted_CPRAVG
plt.plot(df['CPRAVG'],color = 'red', label = 'Real CPR avg')
plt.plot(predicted_CPRAVGplot[:,0], color = 'blue', label = 'Predicted CPR avg')
plt.legend()
# Out:
# [[0.43849292]
#  [0.43847868]
#  [0.43847266]
#  ...
#  [0.43863893]
#  [0.43862298]
#  [0.43859985]]

# %% [markdown]
# Time to predict the future!

# %% [markdown]
# We shall use the previous $200$ data predict $CPRAVG$.

# %%
# starting_record = df.shape[0]
# CPRAVG_real_values = df['CPRAVG']
url_future = "https://raw.githubusercontent.com/RiddhimanRaut/Deep-Learning-based-CPR-estimation/main/Future_test_dataset.csv"
df_future = pd.read_csv(url_future)
df_future.drop(df_future.columns[10],axis = 1, inplace=True)
new_df_train = df_future[0:df_future.shape[0]-1000]
new_df_test = df_future[df_future.shape[0]-1000:df_future.shape[0]]
temp = pd.DataFrame.to_numpy(new_df_train)
length_of_future_prediction = new_df_test.shape[0]
for i in range(length_of_future_prediction):   #Take past 200 data, predict next 1000 values
  print("Predicting CPRAVG for entry:",i)
  #Gathering the past 200 data
  total_df_length = temp.shape[0]
  future_Xinput = temp[total_df_length - 200:total_df_length]
  future_Xinput_scaled = scaler.transform(future_Xinput)
  future_Xinput_scaled_batch = np.array([future_Xinput_scaled[:,:]])
  future_prediction = model.predict(future_Xinput_scaled_batch)
  future_prediction = np.repeat(future_prediction, future_Xinput_scaled.shape[1],axis = -1)
  future_prediction = scaler.inverse_transform(future_prediction)[:,0]
  #Parameters to be set:
  # future_data = df_future.loc[total_df_length - 200+i]
  # future_data = pd.DataFrame.to_numpy(future_data)
  # future_data = future_data[0:10]
  future_data = new_df_test.loc[new_df_train.shape[0]+i]
  future_data = pd.DataFrame.to_numpy(future_data)
  future_data
  future_data[0] = future_prediction[0]
  future_data = future_data.reshape(1,10)
  temp = np.append(temp,future_data, axis = 0)
future_data_numpy = temp[new_df_train.shape[0]:new_df_train.shape[0]+new_df_test.shape[0],:]
CPRAVG_predicted_values = future_data_numpy[:,0]
# print(CPRAVG_predicted_values)
# Out:
# Predicting CPRAVG for entry: 0
# Predicting CPRAVG for entry: 1
# Predicting CPRAVG for entry: 2
# Predicting CPRAVG for entry: 3
# Predicting CPRAVG for entry: 4
# Predicting CPRAVG for entry: 5
# Predicting CPRAVG for entry: 6
# Predicting CPRAVG for entry: 7
# Predicting CPRAVG for entry: 8
# Predicting CPRAVG for entry: 9
# Predicting CPRAVG for entry: 10
# Predicting CPRAVG for entry: 11
# Predicting CPRAVG for entry: 12
# Predicting CPRAVG for entry: 13
# Predicting CPRAVG for entry: 14
# Predicting CPRAVG for entry: 15
# Predicting CPRAVG for entry: 16
# Predicting CPRAVG for entry: 17
# Predicting CPRAVG for entry: 18
# Predicting CPRAVG for entry: 19
# Predicting CPRAVG for entry: 20
# Predicting CPRAVG for entry: 21
# Predicting CPRAVG for entry: 22
# Predicting CPRAVG for entry: 23
# Predicting CPRAVG for entry: 24
# Predicting CPRAVG for entry: 25
# Predicting CPRAVG for entry: 26
# Predicting CPRAVG for entry: 27
# Predicting CPRAVG for entry: 28
# Predicting CPRAVG for entry: 29
# Predicting CPRAVG for entry: 30
# Predicting CPRAVG for entry: 31
# Predicting CPRAVG for entry: 32
# Predicting CPRAVG for entry: 33
# Predicting CPRAVG for entry: 34
# Predicting CPRAVG for entry: 35
# Predicting CPRAVG for entry: 36
# Predicting CPRAVG for entry: 37
# Predicting CPRAVG for entry: 38
# Predicting CPRAVG for entry: 39
# Predicting CPRAVG for entry: 40
# Predicting CPRAVG for entry: 41
# Predicting CPRAVG for entry: 42
# Predicting CPRAVG for entry: 43
# Predicting CPRAVG for entry: 44
# Predicting CPRAVG for entry: 45
# Predicting CPRAVG for entry: 46
# Predicting CPRAVG for entry: 47
# Predicting CPRAVG for entry: 48
# Predicting CPRAVG for entry: 49
# Predicting CPRAVG for entry: 50
# Predicting CPRAVG for entry: 51
# Predicting CPRAVG for entry: 52
# Predicting CPRAVG for entry: 53
# Predicting CPRAVG for entry: 54
# Predicting CPRAVG for entry: 55
# Predicting CPRAVG for entry: 56
# Predicting CPRAVG for entry: 57
# Predicting CPRAVG for entry: 58
# Predicting CPRAVG for entry: 59
# Predicting CPRAVG for entry: 60
# Predicting CPRAVG for entry: 61
# Predicting CPRAVG for entry: 62
# Predicting CPRAVG for entry: 63
# Predicting CPRAVG for entry: 64
# Predicting CPRAVG for entry: 65
# Predicting CPRAVG for entry: 66
# Predicting CPRAVG for entry: 67
# Predicting CPRAVG for entry: 68
# Predicting CPRAVG for entry: 69
# Predicting CPRAVG for entry: 70
# Predicting CPRAVG for entry: 71
# Predicting CPRAVG for entry: 72
# Predicting CPRAVG for entry: 73
# Predicting CPRAVG for entry: 74
# Predicting CPRAVG for entry: 75
# Predicting CPRAVG for entry: 76
# Predicting CPRAVG for entry: 77
# Predicting CPRAVG for entry: 78
# Predicting CPRAVG for entry: 79
# Predicting CPRAVG for entry: 80
# Predicting CPRAVG for entry: 81
# Predicting CPRAVG for entry: 82
# Predicting CPRAVG for entry: 83
# Predicting CPRAVG for entry: 84
# Predicting CPRAVG for entry: 85
# Predicting CPRAVG for entry: 86
# Predicting CPRAVG for entry: 87
# Predicting CPRAVG for entry: 88
# Predicting CPRAVG for entry: 89
# Predicting CPRAVG for entry: 90
# Predicting CPRAVG for entry: 91
# Predicting CPRAVG for entry: 92
# Predicting CPRAVG for entry: 93
# Predicting CPRAVG for entry: 94
# Predicting CPRAVG for entry: 95
# Predicting CPRAVG for entry: 96
# Predicting CPRAVG for entry: 97
# Predicting CPRAVG for entry: 98
# Predicting CPRAVG for entry: 99
# Predicting CPRAVG for entry: 100
# Predicting CPRAVG for entry: 101
# Predicting CPRAVG for entry: 102
# Predicting CPRAVG for entry: 103
# Predicting CPRAVG for entry: 104
# Predicting CPRAVG for entry: 105
# Predicting CPRAVG for entry: 106
# Predicting CPRAVG for entry: 107
# Predicting CPRAVG for entry: 108
# Predicting CPRAVG for entry: 109
# Predicting CPRAVG for entry: 110
# Predicting CPRAVG for entry: 111
# Predicting CPRAVG for entry: 112
# Predicting CPRAVG for entry: 113
# Predicting CPRAVG for entry: 114
# Predicting CPRAVG for entry: 115
# Predicting CPRAVG for entry: 116
# Predicting CPRAVG for entry: 117
# Predicting CPRAVG for entry: 118
# Predicting CPRAVG for entry: 119
# Predicting CPRAVG for entry: 120
# Predicting CPRAVG for entry: 121
# Predicting CPRAVG for entry: 122
# Predicting CPRAVG for entry: 123
# Predicting CPRAVG for entry: 124
# Predicting CPRAVG for entry: 125
# Predicting CPRAVG for entry: 126
# Predicting CPRAVG for entry: 127
# Predicting CPRAVG for entry: 128
# Predicting CPRAVG for entry: 129
# Predicting CPRAVG for entry: 130
# Predicting CPRAVG for entry: 131
# Predicting CPRAVG for entry: 132
# Predicting CPRAVG for entry: 133
# Predicting CPRAVG for entry: 134
# Predicting CPRAVG for entry: 135
# Predicting CPRAVG for entry: 136
# Predicting CPRAVG for entry: 137
# Predicting CPRAVG for entry: 138
# Predicting CPRAVG for entry: 139
# Predicting CPRAVG for entry: 140
# Predicting CPRAVG for entry: 141
# Predicting CPRAVG for entry: 142
# Predicting CPRAVG for entry: 143
# Predicting CPRAVG for entry: 144
# Predicting CPRAVG for entry: 145
# Predicting CPRAVG for entry: 146
# Predicting CPRAVG for entry: 147
# Predicting CPRAVG for entry: 148
# Predicting CPRAVG for entry: 149
# Predicting CPRAVG for entry: 150
# Predicting CPRAVG for entry: 151
# Predicting CPRAVG for entry: 152
# Predicting CPRAVG for entry: 153
# Predicting CPRAVG for entry: 154
# Predicting CPRAVG for entry: 155
# Predicting CPRAVG for entry: 156
# Predicting CPRAVG for entry: 157
# Predicting CPRAVG for entry: 158
# Predicting CPRAVG for entry: 159
# Predicting CPRAVG for entry: 160
# Predicting CPRAVG for entry: 161
# Predicting CPRAVG for entry: 162
# Predicting CPRAVG for entry: 163
# Predicting CPRAVG for entry: 164
# Predicting CPRAVG for entry: 165
# Predicting CPRAVG for entry: 166
# Predicting CPRAVG for entry: 167
# Predicting CPRAVG for entry: 168
# Predicting CPRAVG for entry: 169
# Predicting CPRAVG for entry: 170
# Predicting CPRAVG for entry: 171
# Predicting CPRAVG for entry: 172
# Predicting CPRAVG for entry: 173
# Predicting CPRAVG for entry: 174
# Predicting CPRAVG for entry: 175
# Predicting CPRAVG for entry: 176
# Predicting CPRAVG for entry: 177
# Predicting CPRAVG for entry: 178
# Predicting CPRAVG for entry: 179
# Predicting CPRAVG for entry: 180
# Predicting CPRAVG for entry: 181
# Predicting CPRAVG for entry: 182
# Predicting CPRAVG for entry: 183
# Predicting CPRAVG for entry: 184
# Predicting CPRAVG for entry: 185
# Predicting CPRAVG for entry: 186
# Predicting CPRAVG for entry: 187
# Predicting CPRAVG for entry: 188
# Predicting CPRAVG for entry: 189
# Predicting CPRAVG for entry: 190
# Predicting CPRAVG for entry: 191
# Predicting CPRAVG for entry: 192
# Predicting CPRAVG for entry: 193
# Predicting CPRAVG for entry: 194
# Predicting CPRAVG for entry: 195
# Predicting CPRAVG for entry: 196
# Predicting CPRAVG for entry: 197
# Predicting CPRAVG for entry: 198
# Predicting CPRAVG for entry: 199
# Predicting CPRAVG for entry: 200
# Predicting CPRAVG for entry: 201
# Predicting CPRAVG for entry: 202
# Predicting CPRAVG for entry: 203
# Predicting CPRAVG for entry: 204
# Predicting CPRAVG for entry: 205
# Predicting CPRAVG for entry: 206
# Predicting CPRAVG for entry: 207
# Predicting CPRAVG for entry: 208
# Predicting CPRAVG for entry: 209
# Predicting CPRAVG for entry: 210
# Predicting CPRAVG for entry: 211
# Predicting CPRAVG for entry: 212
# Predicting CPRAVG for entry: 213
# Predicting CPRAVG for entry: 214
# Predicting CPRAVG for entry: 215
# Predicting CPRAVG for entry: 216
# Predicting CPRAVG for entry: 217
# Predicting CPRAVG for entry: 218
# Predicting CPRAVG for entry: 219
# Predicting CPRAVG for entry: 220
# Predicting CPRAVG for entry: 221
# Predicting CPRAVG for entry: 222
# Predicting CPRAVG for entry: 223
# Predicting CPRAVG for entry: 224
# Predicting CPRAVG for entry: 225
# Predicting CPRAVG for entry: 226
# Predicting CPRAVG for entry: 227
# Predicting CPRAVG for entry: 228
# Predicting CPRAVG for entry: 229
# Predicting CPRAVG for entry: 230
# Predicting CPRAVG for entry: 231
# Predicting CPRAVG for entry: 232
# Predicting CPRAVG for entry: 233
# Predicting CPRAVG for entry: 234
# Predicting CPRAVG for entry: 235
# Predicting CPRAVG for entry: 236
# Predicting CPRAVG for entry: 237
# Predicting CPRAVG for entry: 238
# Predicting CPRAVG for entry: 239
# Predicting CPRAVG for entry: 240
# Predicting CPRAVG for entry: 241
# Predicting CPRAVG for entry: 242
# Predicting CPRAVG for entry: 243
# Predicting CPRAVG for entry: 244
# Predicting CPRAVG for entry: 245
# Predicting CPRAVG for entry: 246
# Predicting CPRAVG for entry: 247
# Predicting CPRAVG for entry: 248
# Predicting CPRAVG for entry: 249
# Predicting CPRAVG for entry: 250
# Predicting CPRAVG for entry: 251
# Predicting CPRAVG for entry: 252
# Predicting CPRAVG for entry: 253
# Predicting CPRAVG for entry: 254
# Predicting CPRAVG for entry: 255
# Predicting CPRAVG for entry: 256
# Predicting CPRAVG for entry: 257
# Predicting CPRAVG for entry: 258
# Predicting CPRAVG for entry: 259
# Predicting CPRAVG for entry: 260
# Predicting CPRAVG for entry: 261
# Predicting CPRAVG for entry: 262
# Predicting CPRAVG for entry: 263
# Predicting CPRAVG for entry: 264
# Predicting CPRAVG for entry: 265
# Predicting CPRAVG for entry: 266
# Predicting CPRAVG for entry: 267
# Predicting CPRAVG for entry: 268
# Predicting CPRAVG for entry: 269
# Predicting CPRAVG for entry: 270
# Predicting CPRAVG for entry: 271
# Predicting CPRAVG for entry: 272
# Predicting CPRAVG for entry: 273
# Predicting CPRAVG for entry: 274
# Predicting CPRAVG for entry: 275
# Predicting CPRAVG for entry: 276
# Predicting CPRAVG for entry: 277
# Predicting CPRAVG for entry: 278
# Predicting CPRAVG for entry: 279
# Predicting CPRAVG for entry: 280
# Predicting CPRAVG for entry: 281
# Predicting CPRAVG for entry: 282
# Predicting CPRAVG for entry: 283
# Predicting CPRAVG for entry: 284
# Predicting CPRAVG for entry: 285
# Predicting CPRAVG for entry: 286
# Predicting CPRAVG for entry: 287
# Predicting CPRAVG for entry: 288
# Predicting CPRAVG for entry: 289
# Predicting CPRAVG for entry: 290
# Predicting CPRAVG for entry: 291
# Predicting CPRAVG for entry: 292
# Predicting CPRAVG for entry: 293
# Predicting CPRAVG for entry: 294
# Predicting CPRAVG for entry: 295
# Predicting CPRAVG for entry: 296
# Predicting CPRAVG for entry: 297
# Predicting CPRAVG for entry: 298
# Predicting CPRAVG for entry: 299
# Predicting CPRAVG for entry: 300
# Predicting CPRAVG for entry: 301
# Predicting CPRAVG for entry: 302
# Predicting CPRAVG for entry: 303
# Predicting CPRAVG for entry: 304
# Predicting CPRAVG for entry: 305
# Predicting CPRAVG for entry: 306
# Predicting CPRAVG for entry: 307
# Predicting CPRAVG for entry: 308
# Predicting CPRAVG for entry: 309
# Predicting CPRAVG for entry: 310
# Predicting CPRAVG for entry: 311
# Predicting CPRAVG for entry: 312
# Predicting CPRAVG for entry: 313
# Predicting CPRAVG for entry: 314
# Predicting CPRAVG for entry: 315
# Predicting CPRAVG for entry: 316
# Predicting CPRAVG for entry: 317
# Predicting CPRAVG for entry: 318
# Predicting CPRAVG for entry: 319
# Predicting CPRAVG for entry: 320
# Predicting CPRAVG for entry: 321
# Predicting CPRAVG for entry: 322
# Predicting CPRAVG for entry: 323
# Predicting CPRAVG for entry: 324
# Predicting CPRAVG for entry: 325
# Predicting CPRAVG for entry: 326
# Predicting CPRAVG for entry: 327
# Predicting CPRAVG for entry: 328
# Predicting CPRAVG for entry: 329
# Predicting CPRAVG for entry: 330
# Predicting CPRAVG for entry: 331
# Predicting CPRAVG for entry: 332
# Predicting CPRAVG for entry: 333
# Predicting CPRAVG for entry: 334
# Predicting CPRAVG for entry: 335
# Predicting CPRAVG for entry: 336
# Predicting CPRAVG for entry: 337
# Predicting CPRAVG for entry: 338
# Predicting CPRAVG for entry: 339
# Predicting CPRAVG for entry: 340
# Predicting CPRAVG for entry: 341
# Predicting CPRAVG for entry: 342
# Predicting CPRAVG for entry: 343
# Predicting CPRAVG for entry: 344
# Predicting CPRAVG for entry: 345
# Predicting CPRAVG for entry: 346
# Predicting CPRAVG for entry: 347
# Predicting CPRAVG for entry: 348
# Predicting CPRAVG for entry: 349
# Predicting CPRAVG for entry: 350
# Predicting CPRAVG for entry: 351
# Predicting CPRAVG for entry: 352
# Predicting CPRAVG for entry: 353
# Predicting CPRAVG for entry: 354
# Predicting CPRAVG for entry: 355
# Predicting CPRAVG for entry: 356
# Predicting CPRAVG for entry: 357
# Predicting CPRAVG for entry: 358
# Predicting CPRAVG for entry: 359
# Predicting CPRAVG for entry: 360
# Predicting CPRAVG for entry: 361
# Predicting CPRAVG for entry: 362
# Predicting CPRAVG for entry: 363
# Predicting CPRAVG for entry: 364
# Predicting CPRAVG for entry: 365
# Predicting CPRAVG for entry: 366
# Predicting CPRAVG for entry: 367
# Predicting CPRAVG for entry: 368
# Predicting CPRAVG for entry: 369
# Predicting CPRAVG for entry: 370
# Predicting CPRAVG for entry: 371
# Predicting CPRAVG for entry: 372
# Predicting CPRAVG for entry: 373
# Predicting CPRAVG for entry: 374
# Predicting CPRAVG for entry: 375
# Predicting CPRAVG for entry: 376
# Predicting CPRAVG for entry: 377
# Predicting CPRAVG for entry: 378
# Predicting CPRAVG for entry: 379
# Predicting CPRAVG for entry: 380
# Predicting CPRAVG for entry: 381
# Predicting CPRAVG for entry: 382
# Predicting CPRAVG for entry: 383
# Predicting CPRAVG for entry: 384
# Predicting CPRAVG for entry: 385
# Predicting CPRAVG for entry: 386
# Predicting CPRAVG for entry: 387
# Predicting CPRAVG for entry: 388
# Predicting CPRAVG for entry: 389
# Predicting CPRAVG for entry: 390
# Predicting CPRAVG for entry: 391
# Predicting CPRAVG for entry: 392
# Predicting CPRAVG for entry: 393
# Predicting CPRAVG for entry: 394
# Predicting CPRAVG for entry: 395
# Predicting CPRAVG for entry: 396
# Predicting CPRAVG for entry: 397
# Predicting CPRAVG for entry: 398
# Predicting CPRAVG for entry: 399
# Predicting CPRAVG for entry: 400
# Predicting CPRAVG for entry: 401
# Predicting CPRAVG for entry: 402
# Predicting CPRAVG for entry: 403
# Predicting CPRAVG for entry: 404
# Predicting CPRAVG for entry: 405
# Predicting CPRAVG for entry: 406
# Predicting CPRAVG for entry: 407
# Predicting CPRAVG for entry: 408
# Predicting CPRAVG for entry: 409
# Predicting CPRAVG for entry: 410
# Predicting CPRAVG for entry: 411
# Predicting CPRAVG for entry: 412
# Predicting CPRAVG for entry: 413
# Predicting CPRAVG for entry: 414
# Predicting CPRAVG for entry: 415
# Predicting CPRAVG for entry: 416
# Predicting CPRAVG for entry: 417
# Predicting CPRAVG for entry: 418
# Predicting CPRAVG for entry: 419
# Predicting CPRAVG for entry: 420
# Predicting CPRAVG for entry: 421
# Predicting CPRAVG for entry: 422
# Predicting CPRAVG for entry: 423
# Predicting CPRAVG for entry: 424
# Predicting CPRAVG for entry: 425
# Predicting CPRAVG for entry: 426
# Predicting CPRAVG for entry: 427
# Predicting CPRAVG for entry: 428
# Predicting CPRAVG for entry: 429
# Predicting CPRAVG for entry: 430
# Predicting CPRAVG for entry: 431
# Predicting CPRAVG for entry: 432
# Predicting CPRAVG for entry: 433
# Predicting CPRAVG for entry: 434
# Predicting CPRAVG for entry: 435
# Predicting CPRAVG for entry: 436
# Predicting CPRAVG for entry: 437
# Predicting CPRAVG for entry: 438
# Predicting CPRAVG for entry: 439
# Predicting CPRAVG for entry: 440
# Predicting CPRAVG for entry: 441
# Predicting CPRAVG for entry: 442
# Predicting CPRAVG for entry: 443
# Predicting CPRAVG for entry: 444
# Predicting CPRAVG for entry: 445
# Predicting CPRAVG for entry: 446
# Predicting CPRAVG for entry: 447
# Predicting CPRAVG for entry: 448
# Predicting CPRAVG for entry: 449
# Predicting CPRAVG for entry: 450
# Predicting CPRAVG for entry: 451
# Predicting CPRAVG for entry: 452
# Predicting CPRAVG for entry: 453
# Predicting CPRAVG for entry: 454
# Predicting CPRAVG for entry: 455
# Predicting CPRAVG for entry: 456
# Predicting CPRAVG for entry: 457
# Predicting CPRAVG for entry: 458
# Predicting CPRAVG for entry: 459
# Predicting CPRAVG for entry: 460
# Predicting CPRAVG for entry: 461
# Predicting CPRAVG for entry: 462
# Predicting CPRAVG for entry: 463
# Predicting CPRAVG for entry: 464
# Predicting CPRAVG for entry: 465
# Predicting CPRAVG for entry: 466
# Predicting CPRAVG for entry: 467
# Predicting CPRAVG for entry: 468
# Predicting CPRAVG for entry: 469
# Predicting CPRAVG for entry: 470
# Predicting CPRAVG for entry: 471
# Predicting CPRAVG for entry: 472
# Predicting CPRAVG for entry: 473
# Predicting CPRAVG for entry: 474
# Predicting CPRAVG for entry: 475
# Predicting CPRAVG for entry: 476
# Predicting CPRAVG for entry: 477
# Predicting CPRAVG for entry: 478
# Predicting CPRAVG for entry: 479
# Predicting CPRAVG for entry: 480
# Predicting CPRAVG for entry: 481
# Predicting CPRAVG for entry: 482
# Predicting CPRAVG for entry: 483
# Predicting CPRAVG for entry: 484
# Predicting CPRAVG for entry: 485
# Predicting CPRAVG for entry: 486
# Predicting CPRAVG for entry: 487
# Predicting CPRAVG for entry: 488
# Predicting CPRAVG for entry: 489
# Predicting CPRAVG for entry: 490
# Predicting CPRAVG for entry: 491
# Predicting CPRAVG for entry: 492
# Predicting CPRAVG for entry: 493
# Predicting CPRAVG for entry: 494
# Predicting CPRAVG for entry: 495
# Predicting CPRAVG for entry: 496
# Predicting CPRAVG for entry: 497
# Predicting CPRAVG for entry: 498
# Predicting CPRAVG for entry: 499
# Predicting CPRAVG for entry: 500
# Predicting CPRAVG for entry: 501
# Predicting CPRAVG for entry: 502
# Predicting CPRAVG for entry: 503
# Predicting CPRAVG for entry: 504
# Predicting CPRAVG for entry: 505
# Predicting CPRAVG for entry: 506
# Predicting CPRAVG for entry: 507
# Predicting CPRAVG for entry: 508
# Predicting CPRAVG for entry: 509
# Predicting CPRAVG for entry: 510
# Predicting CPRAVG for entry: 511
# Predicting CPRAVG for entry: 512
# Predicting CPRAVG for entry: 513
# Predicting CPRAVG for entry: 514
# Predicting CPRAVG for entry: 515
# Predicting CPRAVG for entry: 516
# Predicting CPRAVG for entry: 517
# Predicting CPRAVG for entry: 518
# Predicting CPRAVG for entry: 519
# Predicting CPRAVG for entry: 520
# Predicting CPRAVG for entry: 521
# Predicting CPRAVG for entry: 522
# Predicting CPRAVG for entry: 523
# Predicting CPRAVG for entry: 524
# Predicting CPRAVG for entry: 525
# Predicting CPRAVG for entry: 526
# Predicting CPRAVG for entry: 527
# Predicting CPRAVG for entry: 528
# Predicting CPRAVG for entry: 529
# Predicting CPRAVG for entry: 530
# Predicting CPRAVG for entry: 531
# Predicting CPRAVG for entry: 532
# Predicting CPRAVG for entry: 533
# Predicting CPRAVG for entry: 534
# Predicting CPRAVG for entry: 535
# Predicting CPRAVG for entry: 536
# Predicting CPRAVG for entry: 537
# Predicting CPRAVG for entry: 538
# Predicting CPRAVG for entry: 539
# Predicting CPRAVG for entry: 540
# Predicting CPRAVG for entry: 541
# Predicting CPRAVG for entry: 542
# Predicting CPRAVG for entry: 543
# Predicting CPRAVG for entry: 544
# Predicting CPRAVG for entry: 545
# Predicting CPRAVG for entry: 546
# Predicting CPRAVG for entry: 547
# Predicting CPRAVG for entry: 548
# Predicting CPRAVG for entry: 549
# Predicting CPRAVG for entry: 550
# Predicting CPRAVG for entry: 551
# Predicting CPRAVG for entry: 552
# Predicting CPRAVG for entry: 553
# Predicting CPRAVG for entry: 554
# Predicting CPRAVG for entry: 555
# Predicting CPRAVG for entry: 556
# Predicting CPRAVG for entry: 557
# Predicting CPRAVG for entry: 558
# Predicting CPRAVG for entry: 559
# Predicting CPRAVG for entry: 560
# Predicting CPRAVG for entry: 561
# Predicting CPRAVG for entry: 562
# Predicting CPRAVG for entry: 563
# Predicting CPRAVG for entry: 564
# Predicting CPRAVG for entry: 565
# Predicting CPRAVG for entry: 566
# Predicting CPRAVG for entry: 567
# Predicting CPRAVG for entry: 568
# Predicting CPRAVG for entry: 569
# Predicting CPRAVG for entry: 570
# Predicting CPRAVG for entry: 571
# Predicting CPRAVG for entry: 572
# Predicting CPRAVG for entry: 573
# Predicting CPRAVG for entry: 574
# Predicting CPRAVG for entry: 575
# Predicting CPRAVG for entry: 576
# Predicting CPRAVG for entry: 577
# Predicting CPRAVG for entry: 578
# Predicting CPRAVG for entry: 579
# Predicting CPRAVG for entry: 580
# Predicting CPRAVG for entry: 581
# Predicting CPRAVG for entry: 582
# Predicting CPRAVG for entry: 583
# Predicting CPRAVG for entry: 584
# Predicting CPRAVG for entry: 585
# Predicting CPRAVG for entry: 586
# Predicting CPRAVG for entry: 587
# Predicting CPRAVG for entry: 588
# Predicting CPRAVG for entry: 589
# Predicting CPRAVG for entry: 590
# Predicting CPRAVG for entry: 591
# Predicting CPRAVG for entry: 592
# Predicting CPRAVG for entry: 593
# Predicting CPRAVG for entry: 594
# Predicting CPRAVG for entry: 595
# Predicting CPRAVG for entry: 596
# Predicting CPRAVG for entry: 597
# Predicting CPRAVG for entry: 598
# Predicting CPRAVG for entry: 599
# Predicting CPRAVG for entry: 600
# Predicting CPRAVG for entry: 601
# Predicting CPRAVG for entry: 602
# Predicting CPRAVG for entry: 603
# Predicting CPRAVG for entry: 604
# Predicting CPRAVG for entry: 605
# Predicting CPRAVG for entry: 606
# Predicting CPRAVG for entry: 607
# Predicting CPRAVG for entry: 608
# Predicting CPRAVG for entry: 609
# Predicting CPRAVG for entry: 610
# Predicting CPRAVG for entry: 611
# Predicting CPRAVG for entry: 612
# Predicting CPRAVG for entry: 613
# Predicting CPRAVG for entry: 614
# Predicting CPRAVG for entry: 615
# Predicting CPRAVG for entry: 616
# Predicting CPRAVG for entry: 617
# Predicting CPRAVG for entry: 618
# Predicting CPRAVG for entry: 619
# Predicting CPRAVG for entry: 620
# Predicting CPRAVG for entry: 621
# Predicting CPRAVG for entry: 622
# Predicting CPRAVG for entry: 623
# Predicting CPRAVG for entry: 624
# Predicting CPRAVG for entry: 625
# Predicting CPRAVG for entry: 626
# Predicting CPRAVG for entry: 627
# Predicting CPRAVG for entry: 628
# Predicting CPRAVG for entry: 629
# Predicting CPRAVG for entry: 630
# Predicting CPRAVG for entry: 631
# Predicting CPRAVG for entry: 632
# Predicting CPRAVG for entry: 633
# Predicting CPRAVG for entry: 634
# Predicting CPRAVG for entry: 635
# Predicting CPRAVG for entry: 636
# Predicting CPRAVG for entry: 637
# Predicting CPRAVG for entry: 638
# Predicting CPRAVG for entry: 639
# Predicting CPRAVG for entry: 640
# Predicting CPRAVG for entry: 641
# Predicting CPRAVG for entry: 642
# Predicting CPRAVG for entry: 643
# Predicting CPRAVG for entry: 644
# Predicting CPRAVG for entry: 645
# Predicting CPRAVG for entry: 646
# Predicting CPRAVG for entry: 647
# Predicting CPRAVG for entry: 648
# Predicting CPRAVG for entry: 649
# Predicting CPRAVG for entry: 650
# Predicting CPRAVG for entry: 651
# Predicting CPRAVG for entry: 652
# Predicting CPRAVG for entry: 653
# Predicting CPRAVG for entry: 654
# Predicting CPRAVG for entry: 655
# Predicting CPRAVG for entry: 656
# Predicting CPRAVG for entry: 657
# Predicting CPRAVG for entry: 658
# Predicting CPRAVG for entry: 659
# Predicting CPRAVG for entry: 660
# Predicting CPRAVG for entry: 661
# Predicting CPRAVG for entry: 662
# Predicting CPRAVG for entry: 663
# Predicting CPRAVG for entry: 664
# Predicting CPRAVG for entry: 665
# Predicting CPRAVG for entry: 666
# Predicting CPRAVG for entry: 667
# Predicting CPRAVG for entry: 668
# Predicting CPRAVG for entry: 669
# Predicting CPRAVG for entry: 670
# Predicting CPRAVG for entry: 671
# Predicting CPRAVG for entry: 672
# Predicting CPRAVG for entry: 673
# Predicting CPRAVG for entry: 674
# Predicting CPRAVG for entry: 675
# Predicting CPRAVG for entry: 676
# Predicting CPRAVG for entry: 677
# Predicting CPRAVG for entry: 678
# Predicting CPRAVG for entry: 679
# Predicting CPRAVG for entry: 680
# Predicting CPRAVG for entry: 681
# Predicting CPRAVG for entry: 682
# Predicting CPRAVG for entry: 683
# Predicting CPRAVG for entry: 684
# Predicting CPRAVG for entry: 685
# Predicting CPRAVG for entry: 686
# Predicting CPRAVG for entry: 687
# Predicting CPRAVG for entry: 688
# Predicting CPRAVG for entry: 689
# Predicting CPRAVG for entry: 690
# Predicting CPRAVG for entry: 691
# Predicting CPRAVG for entry: 692
# Predicting CPRAVG for entry: 693
# Predicting CPRAVG for entry: 694
# Predicting CPRAVG for entry: 695
# Predicting CPRAVG for entry: 696
# Predicting CPRAVG for entry: 697
# Predicting CPRAVG for entry: 698
# Predicting CPRAVG for entry: 699
# Predicting CPRAVG for entry: 700
# Predicting CPRAVG for entry: 701
# Predicting CPRAVG for entry: 702
# Predicting CPRAVG for entry: 703
# Predicting CPRAVG for entry: 704
# Predicting CPRAVG for entry: 705
# Predicting CPRAVG for entry: 706
# Predicting CPRAVG for entry: 707
# Predicting CPRAVG for entry: 708
# Predicting CPRAVG for entry: 709
# Predicting CPRAVG for entry: 710
# Predicting CPRAVG for entry: 711
# Predicting CPRAVG for entry: 712
# Predicting CPRAVG for entry: 713
# Predicting CPRAVG for entry: 714
# Predicting CPRAVG for entry: 715
# Predicting CPRAVG for entry: 716
# Predicting CPRAVG for entry: 717
# Predicting CPRAVG for entry: 718
# Predicting CPRAVG for entry: 719
# Predicting CPRAVG for entry: 720
# Predicting CPRAVG for entry: 721
# Predicting CPRAVG for entry: 722
# Predicting CPRAVG for entry: 723
# Predicting CPRAVG for entry: 724
# Predicting CPRAVG for entry: 725
# Predicting CPRAVG for entry: 726
# Predicting CPRAVG for entry: 727
# Predicting CPRAVG for entry: 728
# Predicting CPRAVG for entry: 729
# Predicting CPRAVG for entry: 730
# Predicting CPRAVG for entry: 731
# Predicting CPRAVG for entry: 732
# Predicting CPRAVG for entry: 733
# Predicting CPRAVG for entry: 734
# Predicting CPRAVG for entry: 735
# Predicting CPRAVG for entry: 736
# Predicting CPRAVG for entry: 737
# Predicting CPRAVG for entry: 738
# Predicting CPRAVG for entry: 739
# Predicting CPRAVG for entry: 740
# Predicting CPRAVG for entry: 741
# Predicting CPRAVG for entry: 742
# Predicting CPRAVG for entry: 743
# Predicting CPRAVG for entry: 744
# Predicting CPRAVG for entry: 745
# Predicting CPRAVG for entry: 746
# Predicting CPRAVG for entry: 747
# Predicting CPRAVG for entry: 748
# Predicting CPRAVG for entry: 749
# Predicting CPRAVG for entry: 750
# Predicting CPRAVG for entry: 751
# Predicting CPRAVG for entry: 752
# Predicting CPRAVG for entry: 753
# Predicting CPRAVG for entry: 754
# Predicting CPRAVG for entry: 755
# Predicting CPRAVG for entry: 756
# Predicting CPRAVG for entry: 757
# Predicting CPRAVG for entry: 758
# Predicting CPRAVG for entry: 759
# Predicting CPRAVG for entry: 760
# Predicting CPRAVG for entry: 761
# Predicting CPRAVG for entry: 762
# Predicting CPRAVG for entry: 763
# Predicting CPRAVG for entry: 764
# Predicting CPRAVG for entry: 765
# Predicting CPRAVG for entry: 766
# Predicting CPRAVG for entry: 767
# Predicting CPRAVG for entry: 768
# Predicting CPRAVG for entry: 769
# Predicting CPRAVG for entry: 770
# Predicting CPRAVG for entry: 771
# Predicting CPRAVG for entry: 772
# Predicting CPRAVG for entry: 773
# Predicting CPRAVG for entry: 774
# Predicting CPRAVG for entry: 775
# Predicting CPRAVG for entry: 776
# Predicting CPRAVG for entry: 777
# Predicting CPRAVG for entry: 778
# Predicting CPRAVG for entry: 779
# Predicting CPRAVG for entry: 780
# Predicting CPRAVG for entry: 781
# Predicting CPRAVG for entry: 782
# Predicting CPRAVG for entry: 783
# Predicting CPRAVG for entry: 784
# Predicting CPRAVG for entry: 785
# Predicting CPRAVG for entry: 786
# Predicting CPRAVG for entry: 787
# Predicting CPRAVG for entry: 788
# Predicting CPRAVG for entry: 789
# Predicting CPRAVG for entry: 790
# Predicting CPRAVG for entry: 791
# Predicting CPRAVG for entry: 792
# Predicting CPRAVG for entry: 793
# Predicting CPRAVG for entry: 794
# Predicting CPRAVG for entry: 795
# Predicting CPRAVG for entry: 796
# Predicting CPRAVG for entry: 797
# Predicting CPRAVG for entry: 798
# Predicting CPRAVG for entry: 799
# Predicting CPRAVG for entry: 800
# Predicting CPRAVG for entry: 801
# Predicting CPRAVG for entry: 802
# Predicting CPRAVG for entry: 803
# Predicting CPRAVG for entry: 804
# Predicting CPRAVG for entry: 805
# Predicting CPRAVG for entry: 806
# Predicting CPRAVG for entry: 807
# Predicting CPRAVG for entry: 808
# Predicting CPRAVG for entry: 809
# Predicting CPRAVG for entry: 810
# Predicting CPRAVG for entry: 811
# Predicting CPRAVG for entry: 812
# Predicting CPRAVG for entry: 813
# Predicting CPRAVG for entry: 814
# Predicting CPRAVG for entry: 815
# Predicting CPRAVG for entry: 816
# Predicting CPRAVG for entry: 817
# Predicting CPRAVG for entry: 818
# Predicting CPRAVG for entry: 819
# Predicting CPRAVG for entry: 820
# Predicting CPRAVG for entry: 821
# Predicting CPRAVG for entry: 822
# Predicting CPRAVG for entry: 823
# Predicting CPRAVG for entry: 824
# Predicting CPRAVG for entry: 825
# Predicting CPRAVG for entry: 826
# Predicting CPRAVG for entry: 827
# Predicting CPRAVG for entry: 828
# Predicting CPRAVG for entry: 829
# Predicting CPRAVG for entry: 830
# Predicting CPRAVG for entry: 831
# Predicting CPRAVG for entry: 832
# Predicting CPRAVG for entry: 833
# Predicting CPRAVG for entry: 834
# Predicting CPRAVG for entry: 835
# Predicting CPRAVG for entry: 836
# Predicting CPRAVG for entry: 837
# Predicting CPRAVG for entry: 838
# Predicting CPRAVG for entry: 839
# Predicting CPRAVG for entry: 840
# Predicting CPRAVG for entry: 841
# Predicting CPRAVG for entry: 842
# Predicting CPRAVG for entry: 843
# Predicting CPRAVG for entry: 844
# Predicting CPRAVG for entry: 845
# Predicting CPRAVG for entry: 846
# Predicting CPRAVG for entry: 847
# Predicting CPRAVG for entry: 848
# Predicting CPRAVG for entry: 849
# Predicting CPRAVG for entry: 850
# Predicting CPRAVG for entry: 851
# Predicting CPRAVG for entry: 852
# Predicting CPRAVG for entry: 853
# Predicting CPRAVG for entry: 854
# Predicting CPRAVG for entry: 855
# Predicting CPRAVG for entry: 856
# Predicting CPRAVG for entry: 857
# Predicting CPRAVG for entry: 858
# Predicting CPRAVG for entry: 859
# Predicting CPRAVG for entry: 860
# Predicting CPRAVG for entry: 861
# Predicting CPRAVG for entry: 862
# Predicting CPRAVG for entry: 863
# Predicting CPRAVG for entry: 864
# Predicting CPRAVG for entry: 865
# Predicting CPRAVG for entry: 866
# Predicting CPRAVG for entry: 867
# Predicting CPRAVG for entry: 868
# Predicting CPRAVG for entry: 869
# Predicting CPRAVG for entry: 870
# Predicting CPRAVG for entry: 871
# Predicting CPRAVG for entry: 872
# Predicting CPRAVG for entry: 873
# Predicting CPRAVG for entry: 874
# Predicting CPRAVG for entry: 875
# Predicting CPRAVG for entry: 876
# Predicting CPRAVG for entry: 877
# Predicting CPRAVG for entry: 878
# Predicting CPRAVG for entry: 879
# Predicting CPRAVG for entry: 880
# Predicting CPRAVG for entry: 881
# Predicting CPRAVG for entry: 882
# Predicting CPRAVG for entry: 883
# Predicting CPRAVG for entry: 884
# Predicting CPRAVG for entry: 885
# Predicting CPRAVG for entry: 886
# Predicting CPRAVG for entry: 887
# Predicting CPRAVG for entry: 888
# Predicting CPRAVG for entry: 889
# Predicting CPRAVG for entry: 890
# Predicting CPRAVG for entry: 891
# Predicting CPRAVG for entry: 892
# Predicting CPRAVG for entry: 893
# Predicting CPRAVG for entry: 894
# Predicting CPRAVG for entry: 895
# Predicting CPRAVG for entry: 896
# Predicting CPRAVG for entry: 897
# Predicting CPRAVG for entry: 898
# Predicting CPRAVG for entry: 899
# Predicting CPRAVG for entry: 900
# Predicting CPRAVG for entry: 901
# Predicting CPRAVG for entry: 902
# Predicting CPRAVG for entry: 903
# Predicting CPRAVG for entry: 904
# Predicting CPRAVG for entry: 905
# Predicting CPRAVG for entry: 906
# Predicting CPRAVG for entry: 907
# Predicting CPRAVG for entry: 908
# Predicting CPRAVG for entry: 909
# Predicting CPRAVG for entry: 910
# Predicting CPRAVG for entry: 911
# Predicting CPRAVG for entry: 912
# Predicting CPRAVG for entry: 913
# Predicting CPRAVG for entry: 914
# Predicting CPRAVG for entry: 915
# Predicting CPRAVG for entry: 916
# Predicting CPRAVG for entry: 917
# Predicting CPRAVG for entry: 918
# Predicting CPRAVG for entry: 919
# Predicting CPRAVG for entry: 920
# Predicting CPRAVG for entry: 921
# Predicting CPRAVG for entry: 922
# Predicting CPRAVG for entry: 923
# Predicting CPRAVG for entry: 924
# Predicting CPRAVG for entry: 925
# Predicting CPRAVG for entry: 926
# Predicting CPRAVG for entry: 927
# Predicting CPRAVG for entry: 928
# Predicting CPRAVG for entry: 929
# Predicting CPRAVG for entry: 930
# Predicting CPRAVG for entry: 931
# Predicting CPRAVG for entry: 932
# Predicting CPRAVG for entry: 933
# Predicting CPRAVG for entry: 934
# Predicting CPRAVG for entry: 935
# Predicting CPRAVG for entry: 936
# Predicting CPRAVG for entry: 937
# Predicting CPRAVG for entry: 938
# Predicting CPRAVG for entry: 939
# Predicting CPRAVG for entry: 940
# Predicting CPRAVG for entry: 941
# Predicting CPRAVG for entry: 942
# Predicting CPRAVG for entry: 943
# Predicting CPRAVG for entry: 944
# Predicting CPRAVG for entry: 945
# Predicting CPRAVG for entry: 946
# Predicting CPRAVG for entry: 947
# Predicting CPRAVG for entry: 948
# Predicting CPRAVG for entry: 949
# Predicting CPRAVG for entry: 950
# Predicting CPRAVG for entry: 951
# Predicting CPRAVG for entry: 952
# Predicting CPRAVG for entry: 953
# Predicting CPRAVG for entry: 954
# Predicting CPRAVG for entry: 955
# Predicting CPRAVG for entry: 956
# Predicting CPRAVG for entry: 957
# Predicting CPRAVG for entry: 958
# Predicting CPRAVG for entry: 959
# Predicting CPRAVG for entry: 960
# Predicting CPRAVG for entry: 961
# Predicting CPRAVG for entry: 962
# Predicting CPRAVG for entry: 963
# Predicting CPRAVG for entry: 964
# Predicting CPRAVG for entry: 965
# Predicting CPRAVG for entry: 966
# Predicting CPRAVG for entry: 967
# Predicting CPRAVG for entry: 968
# Predicting CPRAVG for entry: 969
# Predicting CPRAVG for entry: 970
# Predicting CPRAVG for entry: 971
# Predicting CPRAVG for entry: 972
# Predicting CPRAVG for entry: 973
# Predicting CPRAVG for entry: 974
# Predicting CPRAVG for entry: 975
# Predicting CPRAVG for entry: 976
# Predicting CPRAVG for entry: 977
# Predicting CPRAVG for entry: 978
# Predicting CPRAVG for entry: 979
# Predicting CPRAVG for entry: 980
# Predicting CPRAVG for entry: 981
# Predicting CPRAVG for entry: 982
# Predicting CPRAVG for entry: 983
# Predicting CPRAVG for entry: 984
# Predicting CPRAVG for entry: 985
# Predicting CPRAVG for entry: 986
# Predicting CPRAVG for entry: 987
# Predicting CPRAVG for entry: 988
# Predicting CPRAVG for entry: 989
# Predicting CPRAVG for entry: 990
# Predicting CPRAVG for entry: 991
# Predicting CPRAVG for entry: 992
# Predicting CPRAVG for entry: 993
# Predicting CPRAVG for entry: 994
# Predicting CPRAVG for entry: 995
# Predicting CPRAVG for entry: 996
# Predicting CPRAVG for entry: 997
# Predicting CPRAVG for entry: 998
# Predicting CPRAVG for entry: 999

# %%
# url_future = "https://raw.githubusercontent.com/RiddhimanRaut/Deep-Learning-based-CPR-estimation/main/Future_test_dataset.csv"
# new_training_dataset = pd.read_csv(url_future)
# new_training_dataset.drop(new_training_dataset.columns[10], axis = 1, inplace=True)
# new_training_dataset_scaled = scaler.transform(new_training_dataset)
# length_of_whole_dataset = new_training_dataset.shape[0]
# new_n_future = 1
# new_n_past = 200
# for i in range(length_of_whole_dataset-1000,length_of_whole_dataset):

# %%
plt.plot(CPRAVG_predicted_values,color = 'blue', label = 'Predicted CPR avg')
df_future2 = pd.read_csv(url_future)
new_CPRAVG = df_future2['CPRAVG'][new_df_train.shape[0]:new_df_train.shape[0]+new_df_test.shape[0]]
new_CPRAVG = pd.DataFrame.to_numpy(new_CPRAVG)
# print(new_CPRAVG)
plt.plot(new_CPRAVG,color = 'red', label = 'New CPR avg')
plt.legend()

# %%
while True:pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-534b7a74019f> in <module>()
# ----> 1 while True:pass
#
# KeyboardInterrupt:
